# %% [markdown]
# # DATA SCIENCE TASK SUBMISSION

# %% [markdown]
# ### Submitted by -  Pragyan Jyoti Dutta

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df =  pd.read_csv('D:\___Datasets\Stirring minfs\KAG_conversion_data.csv')

# %%
df.head()
# Out:
#     ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0  708746              916          103916  30-34      M        15
# 1  708749              916          103917  30-34      M        16
# 2  708771              916          103920  30-34      M        20
# 3  708815              916          103928  30-34      M        28
# 4  708818              916          103928  30-34      M        28
#
#    Impressions  Clicks  Spent  Total_Conversion  Approved_Conversion
# 0         7350       1   1.43                 2                    1
# 1        17861       2   1.82                 2                    0
# 2          693       0   0.00                 1                    0
# 3         4259       1   1.25                 1                    0
# 4         4133       1   1.29                 1                    1

# %%
df.shape
# Out:
# (1143, 11)

# %%
df.describe()
# Out:
#               ad_id  xyz_campaign_id  fb_campaign_id     interest  \
# count  1.143000e+03      1143.000000     1143.000000  1143.000000
# mean   9.872611e+05      1067.382327   133783.989501    32.766404
# std    1.939928e+05       121.629393    20500.308622    26.952131
# min    7.087460e+05       916.000000   103916.000000     2.000000
# 25%    7.776325e+05       936.000000   115716.000000    16.000000
# 50%    1.121185e+06      1178.000000   144549.000000    25.000000
# 75%    1.121804e+06      1178.000000   144657.500000    31.000000
# max    1.314415e+06      1178.000000   179982.000000   114.000000
#
#         Impressions       Clicks        Spent  Total_Conversion  \
# count  1.143000e+03  1143.000000  1143.000000       1143.000000
# mean   1.867321e+05    33.390201    51.360656          2.855643
# std    3.127622e+05    56.892438    86.908418          4.483593
# min    8.700000e+01     0.000000     0.000000          0.000000
# ...

# %%
df.dtypes
# Out:
# ad_id                    int64
# xyz_campaign_id          int64
# fb_campaign_id           int64
# age                     object
# gender                  object
# interest                 int64
# Impressions              int64
# Clicks                   int64
# Spent                  float64
# Total_Conversion         int64
# Approved_Conversion      int64
# dtype: object

# %%
htmp=sns.heatmap(df[["Impressions","Clicks","Spent","Total_Conversion","Approved_Conversion"]].corr(),annot=True ,fmt=".2f", cmap="coolwarm")

# %% [markdown]
# We see that Impressions and Total conversion is more correlated with Aprroved_conversion than Clicks or Spent

# %%
df["xyz_campaign_id"].unique()
# Out:
# array([ 916,  936, 1178], dtype=int64)

# %% [markdown]
# We see that the company is running 3 campaigns with campaign ids- 916,936 adn 1178

# %%
# Let us rename these campaigns for better usability

# %%
df["xyz_campaign_id"].replace({916:"campaign_1",936:"campaign_2",1178:"campaign_3"}, inplace=True)

# %% [markdown]
# ### Let us see which campaign had the highest conversion rate

# %%
sns.countplot(x ='xyz_campaign_id', data = df) 
plt.show()

# %% [markdown]
# We see that campaign 3 with campaign_id 1178 had the most number of ads

# %%
plt.bar(df["xyz_campaign_id"], df["Approved_Conversion"])
plt.ylabel("Approved_Conversion")
plt.title("Campaign vs Approved_Conversion")
plt.show()

# %% [markdown]
# Again we see Campaign 3 had the highest approved conversions

# %%
plt.bar(df["xyz_campaign_id"], df["Total_Conversion"])
plt.ylabel("Total_Conversion")
plt.title("Campaign vs Total_Conversion")
plt.show()

# %% [markdown]
# we see Campaign 3 had the highest total conversions too

# %%
plt.bar(df["xyz_campaign_id"], df["Spent"])
plt.ylabel("Spent")
plt.title("Campaign vs Amount Spent")
plt.show()

# %% [markdown]
# ## Let us explore the age demographic of the campaign

# %%
sns.countplot(x ='age', data = df)  
plt.show()

# %% [markdown]
# We find the majority of the people are of the age group 30 - 34

# %%
sns.barplot(x = df['xyz_campaign_id'], y = df['Approved_Conversion'], hue = df['age'])

# %% [markdown]
# Campaign 1 : age group of 40-44 was the most interested age group
#
# Campaign 2 : almost all age groups were equally interested
#
# Campaign 3 : age group of 30-34 was the most interested age group

# %%
sns.barplot(x = df['xyz_campaign_id'], y = df['Spent'], hue = df['age'])

# %% [markdown]
# We see that all the campaigns spent the most money for the age group of 45-49

# %%
sns.barplot(x = df['xyz_campaign_id'], y = df['Impressions'], hue = df['age'])

# %%
df.head()
# Out:
#     ad_id xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0  708746      campaign_1          103916  30-34      M        15
# 1  708749      campaign_1          103917  30-34      M        16
# 2  708771      campaign_1          103920  30-34      M        20
# 3  708815      campaign_1          103928  30-34      M        28
# 4  708818      campaign_1          103928  30-34      M        28
#
#    Impressions  Clicks  Spent  Total_Conversion  Approved_Conversion
# 0         7350       1   1.43                 2                    1
# 1        17861       2   1.82                 2                    0
# 2          693       0   0.00                 1                    0
# 3         4259       1   1.25                 1                    0
# 4         4133       1   1.29                 1                    1

# %% [markdown]
# Also the age group of 45-49 had the most number of Impressions.

# %%
sns.barplot(x = df['age'], y = df['Spent'], hue = df['gender'])

# %% [markdown]
# It is interesting to note that across all age groups, Females spent more time as compared to males

# %%
sns.barplot(x = df['age'], y = df['Approved_Conversion'], hue = df['gender'])

# %% [markdown]
# Even though the time spent by females was more than males across all categories; males had more approved conversions in the age group of 30-34 while females had more conversions across other age groups

# %%
fig_dims = (15,6)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(x ='interest', data = df)  
plt.show()

# %%
plt.scatter(df["interest"], df["Approved_Conversion"])
plt.title("interest vs. Approved_Conversion")
plt.xlabel("interest")
plt.ylabel("Approved_Conversion")
plt.show()

# %% [markdown]
# It's interesting to note that, although the count of interest after 100 is less,there is a rise of users after 100 who actually bought the product. Rest of the distribution is according to what was expected.

# %%
g = sns.FacetGrid(df, col="gender")
g.map(plt.scatter, "interest", "Approved_Conversion", alpha=.4)
g.add_legend();

# %%
g = sns.FacetGrid(df, col="age")
g.map(plt.scatter, "interest", "Approved_Conversion", alpha=.4)
g.add_legend();

# %% [markdown]
# ### Spent

# %%
plt.hist(df['Spent'], bins = 25)
plt.xlabel("Spent")
plt.ylabel("Frequency")
plt.show()

# %%
plt.scatter(df["Spent"], df["Approved_Conversion"])
plt.title("Spent vs. Approved_Conversion")
plt.xlabel("Spent")
plt.ylabel("Approved_Conversion")
plt.show()

# %% [markdown]
# We can see, as the amount of money spent increases, no of product bought increases.

# %%
g = sns.FacetGrid(df, col="gender")
g.map(plt.scatter, "Spent", "Approved_Conversion", alpha=.4)
g.add_legend();

# %%
g = sns.FacetGrid(df, col="age")
g.map(plt.scatter, "Spent", "Approved_Conversion", alpha=.4)
g.add_legend();

# %%
plt.hist(df['Impressions'], bins = 25)
plt.xlabel("Impressions")
plt.ylabel("Frequency")
plt.show()

# %%
plt.scatter(df["Impressions"], df["Approved_Conversion"])
plt.title("Impressions vs. Approved_Conversion")
plt.xlabel("Impressions")
plt.ylabel("Approved_Conversion")
plt.show()

# %% [markdown]
# There is a sudden rise in Approved conversions after a certain point in Impressions.

# %% [markdown]
# ## Let us check the clicks vs Approved conversion across the demographic

# %%
g = sns.FacetGrid(df, col="gender")
g.map(plt.scatter, "Clicks", "Approved_Conversion", alpha=.4)
g.add_legend();

# %% [markdown]
# It seems like men click more on ads but women tend to buy more products after clicking

# %%
g = sns.FacetGrid(df, col="age")
g.map(plt.scatter, "Clicks", "Approved_Conversion", alpha=.4,)
g.add_legend();

# %% [markdown]
# People in age group 30-34 has more tendency to buy product after clicking the add.

# %% [markdown]
# ## Let us check the Total Conversions vs Approved Conversions across the demographic

# %%
g = sns.FacetGrid(df, col="gender")
g.map(plt.scatter, "Total_Conversion", "Approved_Conversion", alpha=.4)
g.add_legend();

# %% [markdown]
# We see that females tend to buy more products after enquiring about it but men tend to enquire more about the products

# %%
g = sns.FacetGrid(df, col="age")
g.map(plt.scatter, "Total_Conversion", "Approved_Conversion", alpha=.4)
g.add_legend();

# %% [markdown]
# The age group of 30-34 tend to enquire more about the products and also buy more as compared to the other age groups after enquiring about the product.

# %% [markdown]
# # CONCLUSIONS:

# %% [markdown]
# Note: We will use the following convention in the conclusion:
#
#       campaign_id916: campaign_1
#
#       campaign_id936: campaign_2
#
#       campaign_id1178: campaign_3
#
#
# 1. We see that Impressions and Total conversion is more correlated with Aprroved_conversion than Clicks or Spent.
#
# 2. Campaign_3 spent the most amount on ads, had the most number of ads and had the highest approved conversions too.
#
# 3. The age group of 30-34 was the group with most number of Interests
#
# 4. But in Campaign_1, age group of 40-44 had the most interest, which shows that the ad was targeted for older folks.
#
# 5. As the amount of money spent increases, the number of Approved_Conversions increases too.
#
# 6. Women tend to buy more products after clicking on the ads. But men tend to click on more ads.
#
# 7. Women tend to buy more products after enquiring about the ads. But men tend to enquire more.
#
# 8. The age group of 30-34 has more tendency to buy products after clicking on ads and enquiring about it.

# %% [markdown]
# # Business Questions:

# %% [markdown]
# ## 1. How to optimize the social ad campaigns for the highest conversion rate possible? (Attain best Reach to Conversion ratios/Click to Conversion ratios)

# %% [markdown]
# 1. We see that men tend to click more on ads but women tend to buy more products after clicking on the ads. So the target audience for the ads should be women.
#
# 2. We see in Campaign_3, more the number of impressions, more the number of Approved_conversions, therefore the number of ad count should be increased.
#
# 3. The age group of 30-34 should be the primary target audience of these ads.

# %% [markdown]
# ## 2. Finding the perfect target demographics with the appropriate click through rates

# %% [markdown]
# 1. Since women tend to buy more products after clicking on ads, therefore women should be the main target audience.
#
# 2. Also since the age group of 30-34 has a higher chance of buying products after clicking on ads, therefore they should be the main target audience. In short, the ads should be targeted at women of age group 30-34.

# %% [markdown]
# ## 3. Understanding the ideal turnaround/decision making time per age group to convert and re-target future social campaigns

# %% [markdown]
# 1. Age group 30-34 tend to take less decision making time followed by 35 to 39 and 40-44.
# 2. Age group 45-49 take the most time to decide.

# %% [markdown]
# ## 4. Comparing the individual campaign performance so the best creative/campaign can be run again with adjusted audiences.

# %% [markdown]
# 1. Campaign_3 is definately the best campaign as it has the highest Approved_Conversions.
#
# 2. Also campaign_a does pretty well , considering the number of ads it involves. With less no of ads, it has managed to peform better than campaign_b with large no of ads
